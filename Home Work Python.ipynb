# %% [markdown]
# # HOMEWORK PYTHON DSA
# Description    :
# <br> Author    : Wilvan Dany Aritonang
# <br> Date      : 7 October 2019

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### 1. In your Jupyter Notebook or Google Colab, import numpy and pandas library, then perform loading dataset that you have got and stored in a folder named dataset. Typical code for loading dataset is as follows:

# %%
gplay = pd.read_csv("googleplaystore.csv", encoding='latin1')

print("kolom:",len(gplay.columns))
print("baris:",len(gplay))
# Out:
# kolom: 13
# baris: 10841

# %% [markdown]
# #### 2. How many unique apps categories reflected in the dataset?

# %%
gplay['Category'].nunique()
# Out:
# 34

# %% [markdown]
# #### 3. How many unique genres according to the dataset?

# %%
gplay['Genres'].nunique()
# Out:
# 120

# %% [markdown]
# #### 4. Which code is appropriate to drop duplicate values in 'App' column and remove its rows in Python?  Assume dataset was loaded as a pandas data frame variable: google_play_apps.

# %%
gplay.drop_duplicates(subset='App', inplace=True)

# %% [markdown]
# #### 5. Upon removing duplicate of App column, please run the following code to remove a row that contain 'Free' value at the 'Installs' column. You can check first with this code:

# %%
gplay[gplay['Installs']=='Free']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
gplay = gplay[gplay['Installs'] != 'Free']

# %%
gplay['Installs'] = gplay['Installs'].apply(lambda x: x.replace('+', '') if '+' in str(x) else x)

# %%
gplay['Installs'] = gplay['Installs'].apply(lambda x: x.replace(',', '') if ',' in str(x) else x)

# %%
gplay.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %% [markdown]
# #### 6. If you want to convert data type of 'Installs' columns into integer, you can run the following code.

# %%
gplay['Installs'] = gplay['Installs'].astype(int)

# %%
gplay.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs            int32
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %% [markdown]
# #### 7. Match Apps and Category based on provided dataset!

# %%
appcat = gplay.groupby('App').Category.first()

# %%
appcat['FIFA Soccer']
# Out:
# 'SPORTS'

# %%
appcat['File Commander - File Manager/Explorer']
# Out:
# 'BUSINESS'

# %%
appcat['Pinterest']
# Out:
# 'SOCIAL'

# %%
appcat['DU Battery Saver - Battery Charger & Battery Life']
# Out:
# 'TOOLS'

# %%
appcat['Subway Surfers']
# Out:
# 'GAME'

# %%
appcat['Flipboard: News For Our Time']
# Out:
# 'NEWS_AND_MAGAZINES'

# %%
appcat['Dropbox']
# Out:
# 'PRODUCTIVITY'

# %%
appcat['WhatsApp Messenger']
# Out:
# 'COMMUNICATION'

# %% [markdown]
# #### 8. The following applications were installed by more than 1 billion users, EXCEPT ... .

# %%
gplay[gplay['Installs']>1000000]
# Out:
#                                                      App             Category  \
# 2      U Launcher Lite â FREE Live Cool Themes, Hid...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 12                        Tattoo Name On My Photo Editor       ART_AND_DESIGN
# 18                         FlipaClip - Cartoon animation       ART_AND_DESIGN
# 19                                          ibis Paint X       ART_AND_DESIGN
# 37                                    Floor Plan Creator       ART_AND_DESIGN
# 42                            Textgram - write on photos       ART_AND_DESIGN
# 45     Canva: Poster, banner, card maker & graphic de...       ART_AND_DESIGN
# 67                                    Ulysse Speedometer    AUTO_AND_VEHICLES
# 69                           Used cars for sale - Trovit    AUTO_AND_VEHICLES
# 70     Fines of the State Traffic Safety Inspectorate...    AUTO_AND_VEHICLES
# 72         Android Auto - Maps, Media, Messaging & Voice    AUTO_AND_VEHICLES
# 117                        Beauty Camera - Selfie Camera               BEAUTY
# 139                              Wattpad ð Free Books  BOOKS_AND_REFERENCE
# 142                                            Wikipedia  BOOKS_AND_REFERENCE
# 143                                        Amazon Kindle  BOOKS_AND_REFERENCE
# 144                                          Cool Reader  BOOKS_AND_REFERENCE
# 145                         Dictionary - Merriam-Webster  BOOKS_AND_REFERENCE
# 146                        NOOK: Read eBooks & Magazines  BOOKS_AND_REFERENCE
# 149                       FBReader: Favorite Book Reader  BOOKS_AND_REFERENCE
# 152                                    Google Play Books  BOOKS_AND_REFERENCE
# 153                       AlReader -any text book reader  BOOKS_AND_REFERENCE
# 155                  Oxford Dictionary of English : Free  BOOKS_AND_REFERENCE
# 157                           Spanish English Translator  BOOKS_AND_REFERENCE
# 164                                         Ebook Reader  BOOKS_AND_REFERENCE
# 166                                    Read books online  BOOKS_AND_REFERENCE
# 172                                             Ancestry  BOOKS_AND_REFERENCE
# 173                                             HTC Help  BOOKS_AND_REFERENCE
# 179                                         Moon+ Reader  BOOKS_AND_REFERENCE
# 186                         English Dictionary - Offline  BOOKS_AND_REFERENCE
# ...                                                  ...                  ...
# 10423                                   Angry Shark 2016               FAMILY
# 10426                            Strike! Ten Pin Bowling               SPORTS
# 10429                         Talking Tom Bubble Shooter               FAMILY
# 10435                                 Bubble Bird Rescue               FAMILY
# 10493                           Cake Shop - Kids Cooking               FAMILY
# 10504                         Motocross Beach Jumping 3D               FAMILY
# 10506                            Hair saloon - Spa salon               FAMILY
# 10507                               Rope Hero: Vice Town                 GAME
# 10509                     PIP Selfie Camera Photo Editor          PHOTOGRAPHY
# 10513                     Flight Simulator: Fly Plane 3D               FAMILY
# 10521                           Navy Gunner Shoot War 3D                 GAME
# 10549                                 Toy Truck Rally 3D                 GAME
# 10554                                 PRO MX MOTOCROSS 2                 GAME
# 10568                                     Crazy Freekick               SPORTS
# 10636                                 FRONTLINE COMMANDO                 GAME
# 10683                                  Hunting Safari 3D               SPORTS
# 10687                                     Zombie Defense               FAMILY
# 10707                     Photo Editor Collage Maker Pro          PHOTOGRAPHY
# 10710                                      Stylish Fonts      PERSONALIZATION
# 10714                      FunForMobile Ringtones & Chat               SOCIAL
# 10716                Free Slideshow Maker & Video Editor          PHOTOGRAPHY
# 10723                                        Mobile Kick               SPORTS
# 10728  MOD-MASTER for Minecraft PE (Pocket Edition) Free                TOOLS
# 10729                            MX Player Codec (ARMv7)   LIBRARIES_AND_DEMO
# 10731                     FeaturePoints: Free Gift Cards               FAMILY
# 10740                                         PhotoFunia          PHOTOGRAPHY
# 10781                               Modern Strike Online                 GAME
# 10784                                         Big Hunter                 GAME
# 10826          Frim: get new friends on local chat rooms               SOCIAL
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews                Size    Installs  Type Price  \
# 2         4.7    87510                8.7M     5000000  Free     0
# 3         4.5   215644                 25M    50000000  Free     0
# 12        4.2    44829                 20M    10000000  Free     0
# 18        4.3   194216                 39M     5000000  Free     0
# 19        4.6   224399                 31M    10000000  Free     0
# 37        4.1    36639  Varies with device     5000000  Free     0
# 42        4.4   295221  Varies with device    10000000  Free     0
# 45        4.7   174531                 24M    10000000  Free     0
# 67        4.3    40211  Varies with device     5000000  Free     0
# 69        4.2    52530                7.0M     5000000  Free     0
# 70        4.8   116986                 35M     5000000  Free     0
# 72        4.2   271920                 16M    10000000  Free     0
# 117       4.0   113715  Varies with device    10000000  Free     0
# 139       4.6  2914724  Varies with device   100000000  Free     0
# 142       4.4   577550  Varies with device    10000000  Free     0
# 143       4.2   814080  Varies with device   100000000  Free     0
# 144       4.5   246315  Varies with device    10000000  Free     0
# 145       4.5   454060  Varies with device    10000000  Free     0
# 146       4.5   155446  Varies with device    10000000  Free     0
# 149       4.5   203130  Varies with device    10000000  Free     0
# 152       3.9  1433233  Varies with device  1000000000  Free     0
# 153       4.6    90468                5.9M     5000000  Free     0
# 155       4.1   363934                7.1M    10000000  Free     0
# 157       4.2    87873  Varies with device    10000000  Free     0
# 164       4.1    85842                 37M     5000000  Free     0
# 166       4.1    91615                 23M     5000000  Free     0
# 172       4.3    64513  Varies with device     5000000  Free     0
# 173       4.2     8342  Varies with device    10000000  Free     0
# 179       4.4   233757  Varies with device    10000000  Free     0
# 186       4.4   341157                 30M    10000000  Free     0
# ...       ...      ...                 ...         ...   ...   ...
# 10423     4.0    73185                 46M     5000000  Free     0
# 10426     4.2    18584                 49M     5000000  Free     0
# 10429     4.4   687136                 54M    50000000  Free     0
# 10435     4.2    70753                 14M     5000000  Free     0
# 10493     4.3    30668                 33M     5000000  Free     0
# 10504     4.0   105954                 43M    10000000  Free     0
# 10506     4.2    38473                 23M    10000000  Free     0
# 10507     4.4   452589                 99M    10000000  Free     0
# 10509     4.4   156322  Varies with device    10000000  Free     0
# 10513     4.0   660613                 21M    50000000  Free     0
# 10521     4.0   103199                 44M    10000000  Free     0
# 10549     4.0   301895                 25M    50000000  Free     0
# 10554     3.8    25275                 21M     5000000  Free     0
# 10568     3.9    47688                 17M     5000000  Free     0
# 10636     4.4  1351833                 12M    10000000  Free     0
# 10683     4.2    36183                 20M     5000000  Free     0
# 10687     4.3   275048                 41M    10000000  Free     0
# 10707     4.5  1519671  Varies with device   100000000  Free     0
# 10710     3.8   153176                4.3M    10000000  Free     0
# 10714     4.4    68358                7.2M     5000000  Free     0
# 10716     4.2   162564                 11M    10000000  Free     0
# 10723     4.3   111809                 40M    10000000  Free     0
# 10728     4.2   271908                8.1M    10000000  Free     0
# 10729     4.3   332083                6.3M    10000000  Free     0
# 10731     3.9   121321                 46M     5000000  Free     0
# 10740     4.3   316378                4.4M    10000000  Free     0
# 10781     4.3   834117                 44M    10000000  Free     0
# 10784     4.3   245455                 84M    10000000  Free     0
# 10826     4.0    88486  Varies with device     5000000  Free     0
# 10840     4.5   398307                 19M    10000000  Free     0
#
#       Content Rating               Genres      Last Updated  \
# 2           Everyone         Art & Design    August 1, 2018
# 3               Teen         Art & Design      June 8, 2018
# 12              Teen         Art & Design     April 2, 2018
# 18          Everyone         Art & Design    August 3, 2018
# 19          Everyone         Art & Design     July 30, 2018
# 37          Everyone         Art & Design     July 14, 2018
# 42          Everyone         Art & Design     July 30, 2018
# 45          Everyone         Art & Design     July 31, 2018
# 67          Everyone      Auto & Vehicles     July 30, 2018
# 69          Everyone      Auto & Vehicles     July 16, 2018
# 70          Everyone      Auto & Vehicles    August 2, 2018
# 72              Teen      Auto & Vehicles     July 11, 2018
# 117         Everyone               Beauty    August 3, 2017
# 139             Teen    Books & Reference    August 1, 2018
# 142         Everyone    Books & Reference    August 2, 2018
# 143             Teen    Books & Reference     July 27, 2018
# 144         Everyone    Books & Reference     July 17, 2015
# 145         Everyone    Books & Reference      May 18, 2018
# 146             Teen    Books & Reference    April 25, 2018
# 149         Everyone    Books & Reference     June 28, 2018
# 152             Teen    Books & Reference    August 3, 2018
# 153         Everyone    Books & Reference      May 27, 2018
# 155         Everyone    Books & Reference     July 11, 2018
# 157             Teen    Books & Reference      May 28, 2018
# 164         Everyone    Books & Reference     June 25, 2018
# 166       Mature 17+    Books & Reference     June 29, 2018
# 172         Everyone    Books & Reference     July 31, 2018
# 173         Everyone    Books & Reference   August 28, 2017
# 179         Everyone    Books & Reference       May 1, 2018
# 186     Everyone 10+    Books & Reference    March 20, 2018
# ...              ...                  ...               ...
# 10423           Teen           Simulation  November 1, 2017
# 10426       Everyone               Sports     June 27, 2018
# 10429       Everyone               Casual      May 25, 2018
# 10435       Everyone               Puzzle    August 7, 2018
# 10493       Everyone  Casual;Pretend Play     July 16, 2018
# 10504           Teen           Simulation      June 5, 2018
# 10506       Everyone  Casual;Pretend Play    April 11, 2018
# 10507     Mature 17+               Action      July 1, 2018
# 10509       Everyone          Photography  February 1, 2018
# 10513       Everyone           Simulation     March 1, 2017
# 10521           Teen               Action    August 2, 2018
# 10549       Everyone               Racing      May 23, 2018
# 10554       Everyone               Racing   August 11, 2017
# 10568       Everyone               Sports      May 18, 2016
# 10636           Teen               Action  October 28, 2013
# 10683           Teen               Sports  January 20, 2018
# 10687           Teen             Strategy     June 22, 2018
# 10707       Everyone          Photography  February 1, 2018
# 10710       Everyone      Personalization    August 7, 2018
# 10714     Mature 17+               Social       May 7, 2016
# 10716       Everyone          Photography    August 5, 2018
# 10723       Everyone               Sports  February 7, 2018
# 10728       Everyone                Tools    August 2, 2018
# 10729       Everyone     Libraries & Demo    April 23, 2018
# 10731       Everyone        Entertainment  October 22, 2016
# 10740       Everyone          Photography      June 3, 2017
# 10781           Teen               Action     July 30, 2018
# 10784   Everyone 10+               Action      May 31, 2018
# 10826     Mature 17+               Social    March 23, 2018
# 10840       Everyone            Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 12                    3.8          4.1 and up
# 18                  2.2.5        4.0.3 and up
# 19                  5.5.4          4.1 and up
# 37     Varies with device        2.3.3 and up
# 42     Varies with device  Varies with device
# 45                  1.6.1          4.1 and up
# 67     Varies with device  Varies with device
# 69                 4.47.3        4.0.3 and up
# 70                  1.9.7        4.0.3 and up
# 72     Varies with device          5.0 and up
# 117    Varies with device  Varies with device
# 139    Varies with device  Varies with device
# 142    Varies with device  Varies with device
# 143    Varies with device  Varies with device
# 144    Varies with device          1.5 and up
# 145    Varies with device  Varies with device
# 146    Varies with device  Varies with device
# 149    Varies with device  Varies with device
# 152    Varies with device  Varies with device
# 153           1.911805270          2.3 and up
# 155               9.1.363          4.1 and up
# 157    Varies with device  Varies with device
# 164                 5.0.6          4.0 and up
# 166                  3.12          4.1 and up
# 172    Varies with device  Varies with device
# 173           9.00.950462          7.0 and up
# 179    Varies with device  Varies with device
# 186                 3.9.1          4.2 and up
# ...                   ...                 ...
# 10423                 1.6          4.0 and up
# 10426               1.7.0          4.1 and up
# 10429            1.5.3.20          4.1 and up
# 10435               1.8.6        4.0.3 and up
# 10493            2.1.3181        4.0.3 and up
# 10504               1.7.3          4.1 and up
# 10506               1.0.5          4.1 and up
# 10507                 2.2          4.0 and up
# 10509  Varies with device  Varies with device
# 10513                1.32          2.3 and up
# 10521             1.0.7.8          4.2 and up
# 10549               1.4.4          4.1 and up
# 10554                1.10          2.3 and up
# 10568              1.0.15          2.3 and up
# 10636               3.0.3          2.1 and up
# 10683                 1.4          2.1 and up
# 10687                12.2          2.3 and up
# 10707  Varies with device  Varies with device
# 10710                1.17        4.0.3 and up
# 10714                3.22          4.1 and up
# 10716                 5.2          4.0 and up
# 10723              1.0.21          4.1 and up
# 10728               3.3.0          4.0 and up
# 10729              1.9.19          4.0 and up
# 10731                 8.7        4.0.3 and up
# 10740             4.0.7.0          2.3 and up
# 10781              1.25.4          4.1 and up
# 10784               2.8.6          4.0 and up
# 10826  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [1978 rows x 13 columns]

# %%
doluset = gplay.groupby ('App').Installs.first()

# %%
doluset.head
# Out:
# <bound method NDFrame.head of App
# "i DT" FÃºtbol. Todos Somos TÃ©cnicos.                                                                                                            SPORTS
# +Download 4 Instagram Twitter                                                                                                                     SOCIAL
# - Free Comics - Comic Apps                                                                                                                        COMICS
# .R                                                                                                                                                 TOOLS
# /u/app                                                                                                                                     COMMUNICATION
# 058.ba                                                                                                                                NEWS_AND_MAGAZINES
# 1. FC KÃ¶ln App                                                                                                                                   SPORTS
# 10 Best Foods for You                                                                                                                 HEALTH_AND_FITNESS
# 10 Minutes a Day Times Tables                                                                                                                     FAMILY
# 10 WPM Amateur ham radio CW Morse code trainer                                                                                             COMMUNICATION
# 10,000 Quotes DB (Premium)                                                                                                           BOOKS_AND_REFERENCE
# 100 Doors of Revenge                                                                                                                              FAMILY
# 100+ C Programs                                                                                                                                   FAMILY
# 100000+ Messages - DP, Status, Jokes & GIF 2018                                                                                                LIFESTYLE
# 101 C Programming Problems                                                                                                                        FAMILY
# 104 Looking for a job - looking for a job, looking for a job, looking for a part-time job, health checkup, resume, treatment room               BUSINESS
# 11st                                                                                                                                            SHOPPING
# 12 Step Meditations & Sober Prayers AA NA AL-ANON                                                                                              LIFESTYLE
# 14thStreetVet                                                                                                                                    MEDICAL
# 17th Edition Cable Sizer                                                                                                             BOOKS_AND_REFERENCE
# 1800 Contacts - Lens Store                                                                                                                       MEDICAL
# 1LINE â One Line with One Touch                                                                                                                   GAME
# 1st Fed CI Mobile Banking                                                                                                                        FINANCE
# 2 Amateur ham radio CW Morse code practice keys TX                                                                                         COMMUNICATION
# 2-Player Co-op Zombie Shoot                                                                                                                         GAME
# 20 Minuten (CH)                                                                                                                       NEWS_AND_MAGAZINES
# 20 minutes (CH)                                                                                                                       NEWS_AND_MAGAZINES
# 2000 AD Comics and Judge Dredd                                                                                                                    COMICS
# 2017 BN SM Sales Conference                                                                                                                     BUSINESS
# 2017 EMRA Antibiotic Guide                                                                                                                       MEDICAL
#                                                                                                                                             ...
# Å melina .cz inzerÃ¡ty inzerce                                                                                                                  SHOPPING
# Ðim Training for CS                                                                                                                                GAME
# ÐÐ¸Ð»ÐµÑÑ ÐÐÐ CD 2019 PRO                                                                                                        AUTO_AND_VEHICLES
# Ð ÐÐ ÐÐ¾Ð²Ð¾ÑÑÐ¸                                                                                                                 NEWS_AND_MAGAZINES
# Ð ÐµÐµI Smart Remote MP3 CD Player                                                                                                                 TOOLS
# Ø£Ø­Ø¯Ø§Ø« ÙØ­ÙØ§Ø¦Ù | Ø®Ø¨Ø± Ø¹Ø§Ø¬Ù ÙÙ Ø§Ø®Ø¨Ø§Ø± Ø§ÙØ¹Ø§ÙÙ
#                                                                 NEWS_AND_MAGAZINES
# Ø§ÙÙØ§ØªØ­ÙÙ Conquerors                                                                                                                       FAMILY
# ØµÙØ± Ø­Ø±Ù H                                                                                                                           ART_AND_DESIGN
# ÙØ¹Ø¨Ø© ØªÙØ¯Ø± ØªØ±Ø¨Ø­ DZ                                                                                                                     FAMILY
# à¦¬à¦¾à¦à¦²à¦¾ à¦à¦¿à¦­à¦¿ à¦ªà§à¦°à§ BD Bangla TV                                                                                            FAMILY
# à¦¬à¦¾à¦à¦²à¦¾flix                                                                                                                               FAMILY
# áá­ááºá¹ Astrology - Min Thein Kha BayDin                                                                                               LIFESTYLE
# âº MultiCraft â Free Miner! ð                                                                                                                 GAME
# ãMiku AR CameraãMikuture                                                                                                                      FAMILY
# ãRanobbe complete freeã Novelba - Free app that you can read and write novels                                                                 COMICS
# ããªã«ã¬ãBLãç¡æã²ã¼ã                                                                                                                FAMILY
# ãã¼ãªã¼ã²ã¤ãå
# ¬å¼éè²©ï½EJ STYLEï¼ã¤ã¼ã¸ã§ã¤ã¹ã¿ã¤ã«ï¼                                                                   SHOPPING
# ä¸­å½èª AQãªã¹ãã³ã°                                                                                                                       FAMILY
# ä¹å±ç½: Buying a house, selling a house, renting a house                                                                               HOUSE_AND_HOME
# ä¹æNAVITIMEãTimetable & Route Search in Japan Tokyo                                                                             MAPS_AND_NAVIGATION
# ååå§ç¹ä¸EY                                                                                                                          COMMUNICATION
# æ¥æ¬AVåå²                                                                                                                       BOOKS_AND_REFERENCE
# æ¼«å Comics - Manga,Novel and Stories                                                                                                           COMICS
# è±æ¼¢å­å
# ¸ EC Dictionary                                                                                                                        FAMILY
# ê°ì±íì BL ì²«ì¬ë                                                                                                                         COMICS
# ë½í°ë¹ - ê°ì¸ë°©ì¡, ì¸í°ë·ë°©ì¡, BJë°©ì¡                                                                                        VIDEO_PLAYERS
# ð I'm rich                                                                                                                                  LIFESTYLE
# ð WhatsLov: Smileys of love, stickers and GIF                                                                                                  SOCIAL
# ð Smart Ruler âï¸ cm/inch measuring for homework!                                                                                            TOOLS
# ð¥ Football Wallpapers 4K | Full HD Backgrounds ð                                                                                     ENTERTAINMENT
# Name: Category, Length: 9659, dtype: object>

# %%
doluset['Facebook']
# Out:
# 1000000000

# %%
doluset['Google Duo - High Quality Video Calls']
# Out:
# 500000000

# %%
doluset['WhatsApp Messenger']
# Out:
# 1000000000

# %%
doluset['Skype']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4380             try:
# -> 4381                 return libindex.get_value_box(s, key)
#    4382             except IndexError:
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_box()
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.validate_indexer()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-d90cc9ac627c> in <module>
# ----> 1 doluset['Skype']
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4387                     raise InvalidIndexError(key)
#    4388                 else:
# -> 4389                     raise e1
#    4390             except Exception:  # pragma: no cover
#    4391                 raise e1
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4373         try:
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
#    4377             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Skype'

# %% [markdown]
# #### 9. Arrange top COMMUNICATION category apps from the highest number of reviews to the lowest!
#    <br>(Hint: Convert the data type to integer first. It is similar with code that was asked in question 6.

# %%
gplay.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs            int32
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
gplay['Reviews'] = gplay['Reviews'].apply(lambda x: x.replace('.0M', '000000') if '.0M' in str(x) else x)

# %%
gplay['Reviews'] = gplay['Reviews'].astype(int)

# %%
gplay.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int32
# Size               object
# Installs            int32
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
top_com = gplay[gplay.Category=='COMMUNICATION']
top_com_cat=top_com.sort_values('Reviews', ascending=False)

# %%
top_com_cat.loc[:,['App','Reviews']].head(100)
# Out:
#                                                      App   Reviews
# 336                                   WhatsApp Messenger  69119316
# 335           Messenger â Text and Video Chat for Free  56642847
# 378          UC Browser - Fast Download Private & Secure  17712922
# 406                          BBM - Free Calls & Messages  12842860
# 342                                      Viber Messenger  11334799
# 403                          LINE: Free Calls & Messages  10790289
# 391                        Skype - free IM & video calls  10484169
# 338                         Google Chrome: Fast & Secure   9642995
# 449    Truecaller: Caller ID, SMS spam blocking & Dialer   7820209
# 365                                               WeChat   5387333
# 351                        Opera Mini - fast web browser   5149854
# 347                        imo free video calls and chat   4785892
# 340                                                Gmail   4604324
# 345                        Yahoo Mail â Stay Organized   4187998
# 366          UC Browser Mini -Tiny Fast Private & Secure   3648120
# 341                                             Hangouts   3419249
# 370                                             Telegram   3128250
# 344                       Firefox Browser fast & private   3075028
# 395           GO SMS Pro - Messenger, Free Themes, Emoji   2876500
# 407                         KakaoTalk: Free Calls & Text   2546527
# 418        Dolphin Browser - Fast, Private & Adblockð¬   2511130
# 356                       Opera Browser: Fast and Secure   2473509
# 4279                                                 Kik   2451136
# 363                                                  Who   2451083
# 413    CM Browser - Ad Blocker , Fast Download , Privacy   2264916
# 371                Google Duo - High Quality Video Calls   2083237
# 339                Messenger Lite: Free Calls & Messages   1429035
# 424                       DU BrowserâBrowse fast & fun   1133501
# 4739   WhatsCall Free Global Phone Call App & Cheap C...   1130966
# 3892                                                Azar   1092337
# ...                                                  ...       ...
# 337                                    Messenger for SMS    125257
# 429                         ExDialer - Dialer & Contacts    125232
# 458                                          GO Notifier    124346
# 457     Newton Mail - Email App for Gmail, Outlook, IMAP    122595
# 384                        Hangouts Dialer - Call Phones    122498
# 4948                         Adblock Browser for Android    121113
# 434                                Full Screen Caller ID    104990
# 353                                    MegaFon Dashboard     99559
# 8904                  Caller ID & Call Block - DU Caller     93930
# 444                          Call Control - Call Blocker     93825
# 453                                             K-9 Mail     88427
# 388                                  Calls & Text by Mo+     83239
# 10206                        Lite for Facebook Messenger     76498
# 8292                             Your Freedom VPN Client     74497
# 432                       PHONE for Google Voice & GTalk     72065
# 7543   CM Transfer - Share any files with friends nearby     71740
# 348                                             Contacts     66602
# 360                                           Chrome Dev     63543
# 442                       CIA - Caller ID & Call Blocker     60308
# 423                              Web Browser for Android     55098
# 7355                                             Threema     51110
# 373                                            Seznam.cz     46702
# 361                                       Xperia Linkâ¢     45487
# 462                                        mail.com mail     44706
# 9630                      Orfox: Tor Browser for Android     44233
# 416                                      Ninesky Browser     42925
# 368                                           My magenta     42370
# 5588                            Ear Agent: Super Hearing     42329
# 461                                Daum Mail - Next Mail     41420
# 377                                           Omlet Chat     40751
#
# [100 rows x 2 columns]

# %% [markdown]
# #### 10. Arrange top 3 game category apps based on number of installed and rating!

# %%
top_gam = gplay[gplay.Category=='GAME']
top_gam_cat_i=top_gam.sort_values('Rating' and 'Installs',ascending=False)

# %%
top_gam_cat_i.loc[:,['App','Rating','Installs']].head(3)
# Out:
#                    App  Rating    Installs
# 1654    Subway Surfers     4.5  1000000000
# 1655  Candy Crush Saga     4.4   500000000
# 1661      Temple Run 2     4.3   500000000

# %% [markdown]
# #### 11. Submit your Github URL that you used to answer this homework. Make sure you start with http and end with ipynb just like the following URL:
