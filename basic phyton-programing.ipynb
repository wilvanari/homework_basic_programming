# %% [markdown]
# # Basic Python Programming
# Description  : This script is going to show you how to learn Python from the beginning.
# <br> Author  : Wilvan Dany Aritonang
# <br> Date    : 30 September 2019
# <br> Sources : [Google](www.google.com)

# %% [markdown]
# ***

# %% [markdown]
# * Session 1 : Introduction
#     * Arithmatics
#     * Methods
#     * Variables
#     * Function
#     * Loop
# * Session 2 : Pandas and Numpy
#     * Pandas
#     * Numpy
# * Session 3 : Data Cleansing
#     * Drop Duplicates
#     * Adding Missing Data

# %% [markdown]
# *Basic Python Programming*

# %% [markdown]
# **Basic Python Pragramming**

# %%
print ("Hellow World")
# Out:
# Hellow World

# %%
print (2+5)
# Out:
# 7

# %% [markdown]
# ![image 1](https://i.udemycdn.com/course/750x422/1817082_cf8a_9.jpg)

# %%
print (True)
# Out:
# True

# %%
print(type(True
          ))
# Out:
# <class 'bool'>

# %%
Fam = [2,3,4,5,6,7]
print (Fam)
type (Fam)
# Out:
# [2, 3, 4, 5, 6, 7]
# list

# %%
animal = ['cat','dog','mokey']
for animal in animals:
          print(animal)
          nums = [0,1,2,3,4]
          squares = [x ** 2 for x in num]
        print(squares)
# Out:
#   File "<tokenize>", line 6
#     print(squares)
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
a=10
b=20

if a == b:
print('yes')
else:
print('no')
# Out:
#   File "<ipython-input-20-802f01b42297>", line 5
#     print('yes')
#         ^
# IndentationError: expected an indented block

# %%
a=10
b=20
print(a)
# Out:
# 10

# %%
a=10
b=20
if a == b:
print('yes')
else:
print('no')
# Out:
#   File "<ipython-input-22-00023269cd53>", line 4
#     print('yes')
#         ^
# IndentationError: expected an indented block

# %%
a=10
b=20

if a == b:
    print('yes')
else:
    print('no')
# Out:
# no

# %%
nums = [0,1,2,3,4]
squares = [x ** 2 for x in nums]
print(squares)
# Out:
# [0, 1, 4, 9, 16]

# %%
animal = ['cat','dog','mokey']
for animal in animals:
print(animal)
# Out:
#   File "<ipython-input-29-9bd1244ec8da>", line 3
#     print(animal)
#         ^
# IndentationError: expected an indented block

# %%
# Out:
#   File "<ipython-input-30-5fd87a4f8fe5>", line 1
#     countries = ['spain', 'france', 'germany', 'norway’]
#                                                         ^
# SyntaxError: EOL while scanning string literal

# %%
pip3 install numpy
import numpy as np
# Out:
#   File "<ipython-input-31-a370759bdff4>", line 1
#     pip3 install numpy
#                ^
# SyntaxError: invalid syntax

# %%
pip3 install numpy
# Out:
#   File "<ipython-input-32-0a0fc7a77e37>", line 1
#     pip3 install numpy
#                ^
# SyntaxError: invalid syntax

# %%
# !pip install numpy

# %%
# !pip install pandas

# %%
import numpy as np

# %%
import pandas as np

# %%
code = ['US', 'AUS', 'JPN', 'IN', 'RUS', 'MOR', 'EG']
names = ['United States', 'Australia', 'Japan', 'India',
'Russia','Morocco', 'Egypt']
dr = [True, False, False, False, True, True, True]
cpc = [809, 731, 588, 18, 200, 70, 45]

# %%
cars = pd.DataFrame(my_dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-a1f0ff5f3107> in <module>
# ----> 1 cars = pd.DataFrame(my_dict)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
cars = pd.DataFrame(my_dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-a1f0ff5f3107> in <module>
# ----> 1 cars = pd.DataFrame(my_dict)
#
# NameError: name 'my_dict' is not defined

# %%
my_dict = {'ctrcode':code, 'country':names, 'drives_right':dr,
'cars_per_cap':cpc}

# %%
cars = pd.DataFrame(my_dict)

# %%
print(type(cars))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(cars)
# Out:
#   ctrcode        country  drives_right  cars_per_cap
# 0      US  United States          True           809
# 1     AUS      Australia         False           731
# 2     JPN          Japan         False           588
# 3      IN          India         False            18
# 4     RUS         Russia          True           200
# 5     MOR        Morocco          True            70
# 6      EG          Egypt          True            45

# %%
imdb = pd.read_csv('https://raw.githubusercontent.com/scalabretta/GroupProject--IMDB/master/Dataset/IMDB-database-update.csv', encoding='latin1')

# %%
imdb.shape
# Out:
# (3781, 36)

# %%
imdb.tail
# Out:
# <bound method NDFrame.tail of       movie_ID                                movie_title  duration  color  \
# 0            1                                     Avatar       178      1
# 1            2   Pirates of the Caribbean: At World's End       169      1
# 2            3                      The Dark Knight Rises       164      1
# 3            4                               Spider-Man 3       156      1
# 4            5         Batman v Superman: Dawn of Justice       183      1
# 5            6                           Superman Returns       169      1
# 6            7                               Man of Steel       143      1
# 7            8  The Hobbit: The Battle of the Five Armies       164      1
# 8            9                     The Amazing Spider-Man       153      1
# 9           10                                 Robin Hood       156      1
# 10          11                                  King Kong       201      1
# ...

# %%
print(imdb.columns)
# Out:
# Index(['movie_ID', 'movie_title', 'duration', 'color', 'title_year', 'country',
#        'language', 'content_rating', 'budget_USD', 'gross_USD', 'net_USD',
#        'profitable', 'director_name', 'director_top20?', 'director_facebook?',
#        'director_facebook_likes', 'actor_1_name', 'actor_top20?',
#        'actor_1_facebook?', 'actor_1_facebook_likes', 'actor_2_name',
#        'actor_top20?.1', 'actor_2_facebook?', 'actor_2_facebook_likes',
#        'actor_3_name', 'actor_top20?.2', 'actor_3_facebook?',
#        'actor_3_facebook_likes', 'cast_total_facebook_likes',
#        'movie_facebook?', 'movie_facebook_likes;', 'facenumber_in_poster',
#        'num_voted_users', 'num_user_for_reviews', 'imdb_score',
#        'imdb_top_250'],
#       dtype='object')

# %%
imdb[["duration","gross_USD"]].describe()
# Out:
#           duration     gross_USD
# count  3781.000000  3.781000e+03
# mean    109.950278  5.182002e+07
# std      22.299267  7.003776e+07
# min      37.000000  1.620000e+02
# 25%      95.000000  7.605668e+06
# 50%     106.000000  2.896520e+07
# 75%     120.000000  6.600997e+07
# max     325.000000  7.605058e+08

# %%
imdb["language"].value_counts().head(3)
# Out:
# English    3628
# French       33
# Spanish      23
# Name: language, dtype: int64

# %%
imdb["imdb_score"]
# Out:
# 0       7.9
# 1       7.1
# 2       8.5
# 3       6.2
# 4       6.9
# 5       6.1
# 6       7.2
# 7       7.5
# 8       7.0
# 9       6.7
# 10      7.2
# 11      7.7
# 12      8.2
# 13      5.9
# 14      7.0
# 15      7.8
# 16      6.5
# 17      6.8
# 18      7.3
# 19      6.0
# 20      6.7
# 21      6.8
# 22      6.3
# 23      6.6
# 24      7.2
# 25      7.0
# 26      7.8
# 27      7.0
# 28      7.2
# 29      8.4
#        ...
# 3751    4.4
# 3752    6.1
# 3753    5.6
# 3754    5.3
# 3755    5.0
# 3756    7.5
# 3757    5.6
# 3758    5.5
# 3759    6.4
# 3760    6.1
# 3761    6.5
# 3762    4.3
# 3763    6.8
# 3764    6.4
# 3765    6.7
# 3766    2.3
# 3767    4.1
# 3768    3.4
# 3769    5.7
# 3770    5.7
# 3771    6.7
# 3772    5.7
# 3773    7.4
# 3774    6.1
# 3775    5.8
# 3776    5.7
# 3777    7.9
# 3778    5.0
# 3779    7.1
# 3780    7.7
# Name: imdb_score, Length: 3781, dtype: float64

# %%
import numpy as np

# %%
imdb['score_group']=np.where(imdb['imdb_score']>7.5,'high','low')

# %%
imdb
# Out:
#       movie_ID                                movie_title  duration  color  \
# 0            1                                     Avatar       178      1
# 1            2   Pirates of the Caribbean: At World's End       169      1
# 2            3                      The Dark Knight Rises       164      1
# 3            4                               Spider-Man 3       156      1
# 4            5         Batman v Superman: Dawn of Justice       183      1
# 5            6                           Superman Returns       169      1
# 6            7                               Man of Steel       143      1
# 7            8  The Hobbit: The Battle of the Five Armies       164      1
# 8            9                     The Amazing Spider-Man       153      1
# 9           10                                 Robin Hood       156      1
# 10          11                                  King Kong       201      1
# ...
